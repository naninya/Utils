# %%
import os
os.chdir("./src/")
from cleansing_pictures import cleansing_picture, save_cleansing_picture

# %%
import cv2
import matplotlib.pyplot as plt
imgs = cleansing_picture("../input", 150)

fig, ax = plt.subplots(1, len(imgs), figsize=(18, 8 * len(imgs)))
for index, (key, img) in enumerate(imgs.items()):

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax[index].imshow(img)

# %%
# !python ./cleansing_pictures.py --input_dir="../input"
